# %% [markdown]
# # Notebook #2: Limpieza: limpieza y transformación de los datos

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../src')
import funciones as f
import soporte_prep as sp

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', None)

# %%
df_2023 = pd.read_excel('C:\\Users\\DELL\\Downloads\\ParqueVehicular2023_actualizado\\Parque_Vehicular_2023_actualizado.xlsx', sheet_name='2.3.1', skiprows=11, index_col=0)

# %%
df_2023.reset_index(drop=True, inplace=True)

# %%
# Renombrar las columnas manualmente
df_2023.columns = [
    "Provincia", 
    "Automóviles", 
    "Autobuses", 
    "Jeep", 
    "Carga", 
    "Motocicletas", 
    "Volteo", 
    "Máquinas Pesadas", 
    "Otros", 
    "Total", 
    "Total %"
]

df_2023 = df_2023.iloc[1:]

# %%
df_2023 = df_2023.iloc[:33]
df_2023.reset_index(drop=True, inplace=True)
df_2023.columns = df_2023.columns.str.lower()

# %%
df_2023.to_csv('../../Datos/datos_parquev/df_2023.csv')

# %%
df_2023_sin_porc = df_2023.iloc[:,:-1]
df_2023_sin_porc['total'] = df_2023_sin_porc['total'].astype(int)
df_2023_sin_porc.to_csv('../../Datos/datos_parquev/df_2023_sinp.csv')

# %%
df_2023
# Out:
#                  provincia automóviles autobuses    jeep   carga motocicletas  \
# 0                     Azua        7360      1318    4810    6438        51438
# 1                 Bahoruco        2234       381    1304    1089        11265
# 2                 Barahona        6271      1049    4976    3802        43242
# 3                  Dajabón        2474       214    2393    2258        26460
# 4        Distrito Nacional      449502     50151  228951  209711       782430
# 5                   Duarte       23183      2074   13341   12742       120411
# 6                 El Seibo        2290       394    2210    2066        21508
# 7               Elías Piña        1167       161     679     491         4787
# 8                Espaillat       19932      1783   15944   12600        78427
# 9               Hato Mayor        2447       453    2276    2148        23290
# 10        Hermanas Mirabal        7927       813    6464    4864        46505
# ...

# %% [markdown]
# ## Registro Histórico del país

# %%
df_historico = pd.read_excel('C:\\Users\\DELL\\Downloads\\ParqueVehicular2023_actualizado\\Parque_Vehicular_2023_actualizado.xlsx', sheet_name='Serie Histórica', skiprows=5, index_col=0)

# %%
df_historico = df_historico.iloc[1:10,:]

# %%
columnas_historico_int = df_historico.iloc[:, 1:].columns.tolist()
df_historico[columnas_historico_int] = df_historico[columnas_historico_int].astype(int)

# %%
df_historico.reset_index(drop=True, inplace=True)
df_historico
# Out:
#                Tipo    1998     1999     2000     2001     2002     2003  \
# 0     Automóviles1/  380382   406723   444154   475174   506301   514574
# 1         Autobuses   36283    38300    40570    42829    49185    51520
# 2              Jeep   39535    45374    57414    67182    80624    86928
# 3          Carga 2/  183159   197740   217770   231218   248565   255830
# 4      Motocicletas  271753   375023   504307   586844   691074   735565
# 5            Volteo    8387     9542    10653    11431    12606    12820
# 6  Máquinas Pesadas    9246    10124    11206    12180    12927    13166
# 7          Otros 3/    7338     8007     8924     9307     9741     9979
# 8             Total  936083  1090833  1294998  1436165  1611023  1680382
#
#       2004     2005     2006     2007     2008     2009     2010     2011  \
# 0   528178   560880   575386   602291   630115   645258   661747   678732
# 1    53331    56591    58809    62927    67153    69987    73716    76300
# ...

# %%
df_historico['Tipo'] = df_historico['Tipo'].str.replace(r'\d+/.*', '', regex=True).str.strip()

# %%
total_history = df_historico.iloc[[-1]]

# %% [markdown]
# ## Registro del 2024

# %%
df_2024 = pd.read_excel('C:\\Users\\DELL\\Downloads\\ParqueVehicular2024-Recurrente actualizado\\Parque Vehicular.xlsx', sheet_name='Stock vehiculos', skiprows=9)

# %%
df_2024.head()
# Out:
#               Tipo de Vehículo   Cantidad a diciembre 2023* Año 2024  \
# 0                           NaN                         NaN   Enero
# 1                    Ambulancia                     1629.00     1647
# 2              Autobús Privado                    124554.00   125108
# 3  Autobús Público Interurbano                      3646.00     3646
# 4       Autobús Público Urbano                      1305.00     1305
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0    Febrero      Marzo      Abril       Mayo      Junio      Julio
# 1       1655       1657       1662       1670       1681       1687
# 2     125768     126419     127103     127912     128458     129209
# 3       3646       3646       3646       3646       3646       3646
# 4       1305       1305       1305       1305       1305       1305
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0     Agosto  Septiembre     Octubre   Noviembre   Diciembre
# ...

# %%
df_2024 = df_2024.iloc[1:19]

# %%
df_2024.reset_index(drop=True, inplace=True)

# %%
df_2024.columns = [
    'Tipo_Vehiculo',
    "Diciembre_2023", 
    "Enero", 
    "Febrero", 
    "Marzo", 
    "Abril", 
    "Mayo", 
    "Junio", 
    "Julio", 
    "Agosto", 
    "Septiembre", 
    "Octubre", 
    'Noviembre', 
    'Diciembre'
]

# %%
df_2024['Tipo_Vehiculo'] = df_2024['Tipo_Vehiculo'].str.strip()

# %%
df_2024
# Out:
#                       Tipo_Vehiculo  Diciembre_2023    Enero  Febrero  \
# 0                        Ambulancia         1629.00     1647     1655
# 1                   Autobús Privado       124554.00   125108   125768
# 2       Autobús Público Interurbano         3646.00     3646     3646
# 3            Autobús Público Urbano         1305.00     1305     1305
# 4                 Autobús Turístico         1129.00     1128     1128
# 5   Automóvil Interurbano (Público)        10538.00    10539    10539
# 6                 Automóvil Privado      1091755.00  1095702  1098835
# 7          Automóvil Público Urbano        17625.00    17625    17625
# 8               Automóvil Turístico         1777.00     1775     1775
# 9                             Carga       521067.00   523336   525544
# 10                          Fúnebre          314.00      316      318
# 11                             Jeep       678031.00   684094   688993
# ...

# %%
filtro_automovil = df_2024['Tipo_Vehiculo'].str.contains('Automóvil') #filtro para autos
suma_automovil = df_2024.loc[filtro_automovil, 'Diciembre'].sum() # ubico el valor
df_historico.loc[df_historico['Tipo'] == 'Automóviles', '2024'] = suma_automovil #coloco el valor

# %%
df_historico
# Out:
#                Tipo    1998     1999     2000     2001     2002     2003  \
# 0       Automóviles  380382   406723   444154   475174   506301   514574
# 1         Autobuses   36283    38300    40570    42829    49185    51520
# 2              Jeep   39535    45374    57414    67182    80624    86928
# 3             Carga  183159   197740   217770   231218   248565   255830
# 4      Motocicletas  271753   375023   504307   586844   691074   735565
# 5            Volteo    8387     9542    10653    11431    12606    12820
# 6  Máquinas Pesadas    9246    10124    11206    12180    12927    13166
# 7             Otros    7338     8007     8924     9307     9741     9979
# 8             Total  936083  1090833  1294998  1436165  1611023  1680382
#
#       2004     2005     2006     2007     2008     2009     2010     2011  \
# 0   528178   560880   575386   602291   630115   645258   661747   678732
# 1    53331    56591    58809    62927    67153    69987    73716    76300
# ...

# %%
filtro_autobus = df_2024['Tipo_Vehiculo'].str.contains('Autobús')
suma_autobus = df_2024.loc[filtro_autobus, 'Diciembre'].sum()
df_historico.loc[df_historico['Tipo'] == 'Autobuses', '2024'] = suma_autobus
df_historico
# Out:
#                Tipo    1998     1999     2000     2001     2002     2003  \
# 0       Automóviles  380382   406723   444154   475174   506301   514574
# 1         Autobuses   36283    38300    40570    42829    49185    51520
# 2              Jeep   39535    45374    57414    67182    80624    86928
# 3             Carga  183159   197740   217770   231218   248565   255830
# 4      Motocicletas  271753   375023   504307   586844   691074   735565
# 5            Volteo    8387     9542    10653    11431    12606    12820
# 6  Máquinas Pesadas    9246    10124    11206    12180    12927    13166
# 7             Otros    7338     8007     8924     9307     9741     9979
# 8             Total  936083  1090833  1294998  1436165  1611023  1680382
#
#       2004     2005     2006     2007     2008     2009     2010     2011  \
# 0   528178   560880   575386   602291   630115   645258   661747   678732
# 1    53331    56591    58809    62927    67153    69987    73716    76300
# ...

# %%
df_historico.loc[df_historico['Tipo'] == 'Jeep', '2024'] = df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Jeep', 'Diciembre'].values[0]
df_historico.loc[df_historico['Tipo'] == 'Carga', '2024'] = df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Carga', 'Diciembre'].values[0]
df_historico.loc[df_historico['Tipo'] == 'Motocicletas', '2024'] = df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Motocicleta', 'Diciembre'].values[0]
df_historico.loc[df_historico['Tipo'] == 'Volteo', '2024'] = df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Volteo', 'Diciembre'].values[0]
df_historico.loc[df_historico['Tipo'] == 'Máquinas Pesadas', '2024'] = df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Maquina Pesada', 'Diciembre'].values[0]

# %%
df_historico.loc[df_historico['Tipo'] == 'Otros', '2024'] = (df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Ambulancia', 'Diciembre'].values[0] + 
                                                             df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Fúnebre', 'Diciembre'].values[0] + 
                                                             df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Montacarga', 'Diciembre'].values[0] + 
                                                             df_2024.loc[df_2024['Tipo_Vehiculo'] == 'Remolque', 'Diciembre'].values[0])

# %%
df_historico.loc[df_historico['Tipo'] == 'Total', '2024'] = df_historico['2024'].sum()

# %%
df_historico['2024'] = df_historico['2024'].astype(int)

# %%
df_historico.to_csv('../../Datos/datos_parquev/registro_historico_anios_cat.csv')

# %%
df_historico_t = df_historico.T

# %%
df_historico_t.reset_index(inplace=True)

# %%
df_historico_t.columns = df_historico_t.iloc[0]
df_historico_t = df_historico_t[1:]

# %%
df_historico_t.rename(columns={'Tipo':'anio'}, inplace=True)
df_historico_t.columns = df_historico_t.columns.str.lower()

# %%
df_historico_t.rename(columns={'automóviles': 'automoviles', 'máquinas pesadas': 'maquinas_pesadas'}, inplace=True)

# %%
columnas_int_trans = df_historico_t.columns.tolist()

# %%
df_historico_t[columnas_int_trans] = df_historico_t[columnas_int_trans].astype('int64')

# %%
df_historico
# Out:
#                Tipo    1998     1999     2000     2001     2002     2003  \
# 0       Automóviles  380382   406723   444154   475174   506301   514574
# 1         Autobuses   36283    38300    40570    42829    49185    51520
# 2              Jeep   39535    45374    57414    67182    80624    86928
# 3             Carga  183159   197740   217770   231218   248565   255830
# 4      Motocicletas  271753   375023   504307   586844   691074   735565
# 5            Volteo    8387     9542    10653    11431    12606    12820
# 6  Máquinas Pesadas    9246    10124    11206    12180    12927    13166
# 7             Otros    7338     8007     8924     9307     9741     9979
# 8             Total  936083  1090833  1294998  1436165  1611023  1680382
#
#       2004     2005     2006     2007     2008     2009     2010     2011  \
# 0   528178   560880   575386   602291   630115   645258   661747   678732
# 1    53331    56591    58809    62927    67153    69987    73716    76300
# ...

# %%
df_historico_t.to_csv('../../Datos/datos_parquev/df_historico_transpose.csv')
